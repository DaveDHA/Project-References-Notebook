# %% [markdown]
# # Exploring Project References

# %% [markdown]
# ## Instructions

# %% [markdown]
# 1. Under the **Configuration** section, edit the `slnFolder` to the absolute path of the folder containing your solution.
# 2. Under the **Configuration** section, edit the `samplePath` to choose a specific project that will be used by the type provider to examine the project XML. Choose a good sample project with a robust project file that at least includes some project references, or the type provider won't be able to parse your projects.
# 3. Run all cells in the **Configuration** and **Setting Up** sections.
# 4. In the **Viewing Project Reference Information** section, run the cells you are interested in.  You may need to edit some project names to view projects you are interested in.  Project names are case-sensitive, so you may want to copy-paste from **A list of all projects under the solution folder**.
#
# The diagram under **All Project References in the solution** gets pretty rough for large projects.  Looking at specific projects will likely be must more useful.
#
# If you switch to a different `slnFolder`, it is best to `Restart` the notebook to make sure that the type provider is refreshed.

# %% [markdown]
# ## Configuration

# %%
[<Literal>]
let slnFolder = @"C:\Dev\Github projects\interactive"

[<Literal>] 
let samplePath = @".\src\Microsoft.Dotnet.Interactive.CSharp\Microsoft.DotNet.Interactive.CSharp.csproj"

let excludeTestProjects = false

# %% [markdown]
# ## Setting Up

# %% [markdown]
# The following cells set up the rest of the notebook.

# %%
#r "nuget: FSharp.Data"
#r "nuget: ChickenScratch"
open FSharp.Data
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>ChickenScratch, 1.1.0</span></li><li><span>FSharp.Data, 5.0.2</span></li></ul></div></div>

# %%
type ProjectXml = XmlProvider<samplePath, ResolutionFolder=slnFolder>

// Sometimes on the first run, the type provider takes a bit to load.  This is a hack to make sure it's loaded before we try to use it.
Async.Sleep 1000 |> Async.RunSynchronously

# %%
type PrelimProjectInfo = {
    Name : string
    References : string list
}

module PrelimProjectInfo =
    let getProjectName (str : String) =
        str.Replace(".csproj", "").Replace(".fsproj", "")
    
    
    let FromFileInfo (fi : FileInfo) =
        let proj = ProjectXml.Load fi.FullName
        let refs = proj.ItemGroups |> Seq.collect (fun ig -> 
            ig.ProjectReferences 
            |> Seq.map (fun pr -> pr.Include) 
            |> Seq.filter (fun s -> not (excludeTestProjects && s.Contains "Test")))
            
        let names = refs |> Seq.map (fun r -> FileInfo(r).Name |> getProjectName)
        { Name = fi.Name |> getProjectName ; References = names |> Seq.toList }


    let FromFileInfos fis =
        fis 
        |> Seq.map (fun fi -> FromFileInfo fi)
        |> Seq.filter (fun pi -> not (excludeTestProjects && pi.Name.Contains "Test" )) 
        |> Seq.toList 


    let FromFolder path = 
        DirectoryInfo(slnFolder).GetFiles("*.*proj", SearchOption.AllDirectories)
        |> Seq.filter (fun fi -> fi.Extension <> ".deployproj")
        |> FromFileInfos

# %%
type ProjectInfo = {
    Name : string
    References : string list
    ReferencedBy : string list
}


module ProjectInfo =
    let FromPrelim (prelims : PrelimProjectInfo seq) (target : PrelimProjectInfo) =
        {
            Name = target.Name
            References = target.References |> List.sort
            ReferencedBy = 
                prelims
                |> Seq.filter (fun p -> p.References |> Seq.contains target.Name)
                |> Seq.map (fun p -> p.Name)
                |> Seq.sort
                |> Seq.toList
        }

    let FromPrelims (prelims : PrelimProjectInfo seq) =
        prelims |> Seq.map (fun p -> FromPrelim prelims p) |> Seq.sortBy(fun p -> p.Name) |> Seq.toList


    let FromFolder path = path |> PrelimProjectInfo.FromFolder |> FromPrelims


    
        

let projInfos = ProjectInfo.FromFolder slnFolder

# %%
type DiagramDirection = 
| LeftToRight
| RightToLeft
| TopToBottom
| BottomToTop
with
    static member toMermaid reverse (dir : DiagramDirection) =
        match dir, reverse with
        | LeftToRight, false 
        | RightToLeft, true -> "direction LR"
        | RightToLeft, false
        | LeftToRight, true -> "direction RL"
        | BottomToTop, true
        | TopToBottom, false-> "direction TB"
        | TopToBottom, true
        | BottomToTop, false -> "direction BT"


module Show =
    open ChickenScratch
    open ChickenScratch.HtmlExpressions

    let getRelationOutput getRelation (extraInfo : string) (infos : ProjectInfo list) proj =
        let rec loop collapsed proj = 
            li { 
                let chkId = Guid.NewGuid().ToString()
                input { _type "checkbox" ; _id chkId ; if collapsed then _checked "checked" }
                label { _for chkId ; proj.Name }
                span { _class "extraInfo" ;  extraInfo }
                ul { 
                    yield! 
                        proj
                        |> getRelation
                        |> List.collect (fun name -> 
                            infos
                            |> List.filter (fun pi -> pi.Name = name) 
                            |> List.map (loop true)
                        )                    
                }
            }            
        
        div {            
            style {
                ".projInfoRefs .extraInfo { font-size: 0.9em; font-style: italic ; color: gray }"
                ".projInfoRefs ul { list-style-type: none; }"
                ".projInfoRefs input { display: none; }"            
                ".projInfoRefs input:checked ~ ul { display: none; }"
                ".projInfoRefs input ~ label { font-weight: bold; }"
                RawContent ".projInfoRefs input ~ label::before { content: '(-) '; }"
                RawContent ".projInfoRefs input:checked ~ label::before { content: '(+) '; }"
            }
            div {
                _class "projInfoRefs"
                ul { loop false (infos |> List.find (fun pi -> pi.Name = proj)) }
            }        
        }
        
    let allNames projInfos =
        div {
            style { 
                ".projInfoNames ul { list-style-type: none; }"
                ".projInfoNames li { font-weight: bold; }"
            }
            div {
                _class "profInfoNames"
                ul {
                    yield! projInfos |> List.map (fun pi -> li { pi.Name })
                }
            }    
        }

    let AllProjectsReferencedBy proj = 
        (getRelationOutput (fun pi -> pi.References) "references:" projInfos proj).ToString().DisplayAs("text/html") |> ignore
    
    let AllProjectsThatReference proj = 
        (getRelationOutput (fun pi -> pi.ReferencedBy) "is referenced by:" projInfos proj).ToString().DisplayAs("text/html") |> ignore

    let AllProjects() = (allNames projInfos).ToString().DisplayAs("text/html") |> ignore

    module Diagram =
        open Microsoft.DotNet.Interactive
        open Microsoft.DotNet.Interactive.Commands
        
        let clean (str : String) = str.Replace(".", "_").Replace("-", "_")

        let getAllRelationOutput getRelation dir (infos: ProjectInfo list) =            
            seq {
                yield "stateDiagram-v2"
                yield dir |> DiagramDirection.toMermaid false
                yield! infos |> Seq.collect (fun pi -> pi |> getRelation |> Seq.map (fun r -> $"{clean pi.Name} --> {clean r}"))
            }
            |> String.concat "\n"

        let rec getRelationOutput getRelation reverse dir (infos: ProjectInfo list) (targets : string list) = 
            let mapToStr target rel =
                if reverse then $"{clean rel} --> {clean target}"
                else $"{clean target} --> {clean rel}"

            let rec loop (targets : string list) = seq {
                match targets with
                | [] -> ()
                | h :: t -> 
                    let target = infos |> List.find (fun pi -> pi.Name = h)
                    let rels = target |> getRelation
                    yield! rels |> Seq.map (mapToStr target.Name)
                    yield! loop (t @ rels |> List.distinct)
            }

            seq {                
                yield "stateDiagram-v2"                
                yield dir |> DiagramDirection.toMermaid reverse
                yield! loop targets
            }
            |> String.concat "\n"

            


        let AllReferences dir = 
            let diagram = getAllRelationOutput (fun pi -> pi.References) dir projInfos            
            Kernel.Root.SendAsync(new SubmitCode(diagram, "mermaid")) |> Async.AwaitTask |> Async.RunSynchronously |> ignore

        let AllProjectsReferencedBy dir targets =
            let diagram = getRelationOutput (fun pi -> pi.References) false dir projInfos targets
            Kernel.Root.SendAsync(new SubmitCode(diagram, "mermaid")) |> Async.AwaitTask |> Async.RunSynchronously |> ignore
            
        let AllProjectsThatReference dir targets =
            let diagram = getRelationOutput (fun pi -> pi.ReferencedBy) true dir projInfos targets
            Kernel.Root.SendAsync(new SubmitCode(diagram, "mermaid")) |> Async.AwaitTask |> Async.RunSynchronously |> ignore

# %% [markdown]
# ## Viewing Project Reference Information

# %% [markdown]
# ### A list of all projects under the solution folder

# %%
Show.AllProjects()
# Out:
# <div>
#     <style>
#         .projInfoNames ul { list-style-type: none; }
#         .projInfoNames li { font-weight: bold; }
#     </style>
#     <div class="profInfoNames">
#         <ul>
#             <li>BasicConsoleApp</li>
#             <li>ClockExtension</li>
#             <li>FSharpConsole</li>
#             <li>Library</li>
#             <li>Library.InteractiveExtension</li>
#             <li>Library.nuget</li>
#             <li>Microsoft.DotNet.Interactive</li>
#             <li>Microsoft.DotNet.Interactive.ApiCompatibility.Tests</li>
#             <li>Microsoft.DotNet.Interactive.AspNetCore</li>
#             <li>Microsoft.DotNet.Interactive.AspNetCore.Tests</li>
#             <li>Microsoft.DotNet.Interactive.Browser</li>
#             <li>Microsoft.DotNet.Interactive.Browser.Tests</li>
#             <li>Microsoft.DotNet.Interactive.CSharp</li>
#             <li>Microsoft.DotNet.Interactive.CSharp.Tests</li>
#             <li>Microsoft.DotNet.Interactive.CSharpProject</li>
#             <li>Microsoft.DotNet.Interactive.CSharpProject.Tests</li>
#             <li>Microsoft.DotNet.Interactive.Documents</li>
#             <li>Microsoft.DotNet.Interactive.Documents.Tests</li>
#             <li>Microsoft.DotNet.Interactive.ExtensionLab</li>
#             <li>Microsoft.DotNet.Interactive.ExtensionLab.Tests</li>
#             <li>Microsoft.DotNet.Interactive.FSharp</li>
#             <li>Microsoft.DotNet.Interactive.FSharp.Tests</li>
#             <li>Microsoft.DotNet.Interactive.Formatting</li>
#             <li>Microsoft.DotNet.Interactive.Formatting.Tests</li>
#             <li>Microsoft.DotNet.Interactive.Http</li>
#             <li>Microsoft.DotNet.Interactive.HttpRequest</li>
#             <li>Microsoft.DotNet.Interactive.HttpRequest.Tests</li>
#             <li>Microsoft.DotNet.Interactive.Journey</li>
#             <li>Microsoft.DotNet.Interactive.Journey.Tests</li>
#             <li>Microsoft.DotNet.Interactive.Jupyter</li>
#             <li>Microsoft.DotNet.Interactive.Jupyter.Tests</li>
#             <li>Microsoft.DotNet.Interactive.Kql</li>
#             <li>Microsoft.DotNet.Interactive.Kql.Tests</li>
#             <li>Microsoft.DotNet.Interactive.Mermaid</li>
#             <li>Microsoft.DotNet.Interactive.Mermaid.Tests</li>
#             <li>Microsoft.DotNet.Interactive.Netstandard20</li>
#             <li>Microsoft.DotNet.Interactive.PackageManagement</li>
#             <li>Microsoft.DotNet.Interactive.PowerShell</li>
#             <li>Microsoft.DotNet.Interactive.PowerShell.Tests</li>
#             <li>Microsoft.DotNet.Interactive.SqlServer</li>
#             <li>Microsoft.DotNet.Interactive.SqlServer.Tests</li>
#             <li>Microsoft.DotNet.Interactive.Telemetry</li>
#             <li>Microsoft.DotNet.Interactive.Telemetry.Tests</li>
#             <li>Microsoft.DotNet.Interactive.Tests</li>
#             <li>Microsoft.DotNet.Interactive.VSCode</li>
#             <li>Microsoft.Dotnet.Interactive.Shared.shproj</li>
#             <li>RandomNumber</li>
#             <li>SampleExtensions.Tests</li>
#             <li>Tools</li>
#             <li>WpfConnect</li>
#             <li>dotnet-interactive</li>
#             <li>dotnet-interactive.Tests</li>
#             <li>helixpublish.proj</li>
#             <li>interface-generator</li>
#             <li>perf-tests</li>
#         </ul>
#     </div>
# </div>

# %% [markdown]
# ### All Project References in the solution

# %%
Show.Diagram.AllReferences LeftToRight
# Out:
# <div class="mermaidMarkdownContainer" style="background-color:white">
# <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.2.0/css/all.min.css">
# <script type="text/javascript">
#
# loadMermaid_0f422c47252844ea927dfe6cdd14ebfe = () => {
#
#         (require.config({ 'paths': { 'context': '9.1.7', 'mermaidUri' : 'https://cdn.jsdelivr.net/npm/mermaid@9.1.7/dist/mermaid.min', 'urlArgs': 'cacheBuster=abdbfa4a17be4f5a828710a22bd81adc' }}) || require)(['mermaidUri'], (mermaid) => {
#
#             let renderTarget = document.getElementById('0f422c47252844ea927dfe6cdd14ebfe');
#             mermaid.mermaidAPI.render(
#                 'mermaid_0f422c47252844ea927dfe6cdd14ebfe',
#                 `stateDiagram-v2
# direction LR
# Library_InteractiveExtension --> Library
# Library_nuget --> Library
# Library_nuget --> Library_InteractiveExtension
# Microsoft_DotNet_Interactive --> Microsoft_DotNet_Interactive_Documents
# Microsoft_DotNet_Interactive --> Microsoft_DotNet_Interactive_Formatting
# Microsoft_DotNet_Interactive_ApiCompatibility_Tests --> Microsoft_DotNet_Interactive
# Microsoft_DotNet_Interactive_ApiCompatibility_Tests --> Microsoft_DotNet_Interactive_CSharp
# Microsoft_DotNet_Interactive_ApiCompatibility_Tests --> Microsoft_DotNet_Interactive_CSharpProject
# Microsoft_DotNet_Interactive_ApiCompatibility_Tests --> Microsoft_DotNet_Interactive_Documents
# Microsoft_DotNet_Interactive_ApiCompatibility_Tests --> Microsoft_DotNet_Interactive_FSharp
# Microsoft_DotNet_Interactive_ApiCompatibility_Tests --> Microsoft_DotNet_Interactive_Formatting
# Microsoft_DotNet_Interactive_ApiCompatibility_Tests --> Microsoft_DotNet_Interactive_HttpRequest
# Microsoft_DotNet_Interactive_ApiCompatibility_Tests --> Microsoft_DotNet_Interactive_Journey
# Microsoft_DotNet_Interactive_ApiCompatibility_Tests --> Microsoft_DotNet_Interactive_Jupyter
# Microsoft_DotNet_Interactive_ApiCompatibility_Tests --> Microsoft_DotNet_Interactive_Kql
# Microsoft_DotNet_Interactive_ApiCompatibility_Tests --> Microsoft_DotNet_Interactive_Mermaid
# Microsoft_DotNet_Interactive_ApiCompatibility_Tests --> Microsoft_DotNet_Interactive_PackageManagement
# Microsoft_DotNet_Interactive_ApiCompatibility_Tests --> Microsoft_DotNet_Interactive_PowerShell
# Microsoft_DotNet_Interactive_ApiCompatibility_Tests --> Microsoft_DotNet_Interactive_SqlServer
# Microsoft_DotNet_Interactive_AspNetCore --> Microsoft_DotNet_Interactive_CSharp
# Microsoft_DotNet_Interactive_AspNetCore_Tests --> Microsoft_DotNet_Interactive_AspNetCore
# Microsoft_DotNet_Interactive_AspNetCore_Tests --> Microsoft_DotNet_Interactive_Tests
# Microsoft_DotNet_Interactive_AspNetCore_Tests --> dotnet_interactive
# Microsoft_DotNet_Interactive_AspNetCore_Tests --> interface_generator
# Microsoft_DotNet_Interactive_Browser --> Microsoft_DotNet_Interactive
# Microsoft_DotNet_Interactive_Browser_Tests --> Microsoft_DotNet_Interactive_Browser
# Microsoft_DotNet_Interactive_Browser_Tests --> Microsoft_DotNet_Interactive_Tests
# Microsoft_DotNet_Interactive_CSharp --> Microsoft_DotNet_Interactive
# Microsoft_DotNet_Interactive_CSharp --> Microsoft_DotNet_Interactive_Formatting
# Microsoft_DotNet_Interactive_CSharp --> Microsoft_DotNet_Interactive_PackageManagement
# Microsoft_DotNet_Interactive_CSharp_Tests --> Microsoft_DotNet_Interactive_CSharp
# Microsoft_DotNet_Interactive_CSharp_Tests --> Microsoft_DotNet_Interactive_Tests
# Microsoft_DotNet_Interactive_CSharpProject --> Microsoft_DotNet_Interactive
# Microsoft_DotNet_Interactive_CSharpProject_Tests --> Microsoft_DotNet_Interactive_CSharpProject
# Microsoft_DotNet_Interactive_CSharpProject_Tests --> Microsoft_DotNet_Interactive_Tests
# Microsoft_DotNet_Interactive_Documents_Tests --> Microsoft_DotNet_Interactive_Documents
# Microsoft_DotNet_Interactive_Documents_Tests --> Microsoft_DotNet_Interactive_Formatting
# Microsoft_DotNet_Interactive_Documents_Tests --> Microsoft_DotNet_Interactive_Tests
# Microsoft_DotNet_Interactive_ExtensionLab --> Microsoft_DotNet_Interactive
# Microsoft_DotNet_Interactive_ExtensionLab --> Microsoft_DotNet_Interactive_CSharp
# Microsoft_DotNet_Interactive_ExtensionLab --> Microsoft_DotNet_Interactive_Formatting
# Microsoft_DotNet_Interactive_ExtensionLab_Tests --> Microsoft_DotNet_Interactive_CSharp
# Microsoft_DotNet_Interactive_ExtensionLab_Tests --> Microsoft_DotNet_Interactive_ExtensionLab
# Microsoft_DotNet_Interactive_ExtensionLab_Tests --> Microsoft_DotNet_Interactive_FSharp
# Microsoft_DotNet_Interactive_ExtensionLab_Tests --> Microsoft_DotNet_Interactive_Mermaid
# Microsoft_DotNet_Interactive_FSharp --> Microsoft_DotNet_Interactive
# Microsoft_DotNet_Interactive_FSharp --> Microsoft_DotNet_Interactive_Formatting
# Microsoft_DotNet_Interactive_FSharp --> Microsoft_DotNet_Interactive_PackageManagement
# Microsoft_DotNet_Interactive_FSharp_Tests --> Microsoft_DotNet_Interactive_FSharp
# Microsoft_DotNet_Interactive_Formatting_Tests --> Microsoft_DotNet_Interactive_Formatting
# Microsoft_DotNet_Interactive_Http --> Microsoft_DotNet_Interactive
# Microsoft_DotNet_Interactive_HttpRequest --> Microsoft_DotNet_Interactive
# Microsoft_DotNet_Interactive_HttpRequest --> Microsoft_DotNet_Interactive_Formatting
# Microsoft_DotNet_Interactive_HttpRequest_Tests --> Microsoft_DotNet_Interactive_HttpRequest
# Microsoft_DotNet_Interactive_HttpRequest_Tests --> Microsoft_DotNet_Interactive_Tests
# Microsoft_DotNet_Interactive_Journey --> Microsoft_DotNet_Interactive
# Microsoft_DotNet_Interactive_Journey --> Microsoft_DotNet_Interactive_CSharp
# Microsoft_DotNet_Interactive_Journey --> Microsoft_DotNet_Interactive_Documents
# Microsoft_DotNet_Interactive_Journey --> Microsoft_DotNet_Interactive_PackageManagement
# Microsoft_DotNet_Interactive_Journey_Tests --> Microsoft_DotNet_Interactive_Journey
# Microsoft_DotNet_Interactive_Journey_Tests --> Microsoft_DotNet_Interactive_Tests
# Microsoft_DotNet_Interactive_Jupyter --> Microsoft_DotNet_Interactive
# Microsoft_DotNet_Interactive_Jupyter --> Microsoft_DotNet_Interactive_CSharp
# Microsoft_DotNet_Interactive_Jupyter --> Microsoft_DotNet_Interactive_Documents
# Microsoft_DotNet_Interactive_Jupyter --> Microsoft_DotNet_Interactive_FSharp
# Microsoft_DotNet_Interactive_Jupyter --> Microsoft_DotNet_Interactive_PowerShell
# Microsoft_DotNet_Interactive_Jupyter_Tests --> Microsoft_DotNet_Interactive_Formatting_Tests
# Microsoft_DotNet_Interactive_Jupyter_Tests --> Microsoft_DotNet_Interactive_Jupyter
# Microsoft_DotNet_Interactive_Jupyter_Tests --> Microsoft_DotNet_Interactive_Tests
# Microsoft_DotNet_Interactive_Kql --> Microsoft_DotNet_Interactive
# Microsoft_DotNet_Interactive_Kql --> Microsoft_DotNet_Interactive_PackageManagement
# Microsoft_DotNet_Interactive_Kql_Tests --> Microsoft_DotNet_Interactive_CSharp
# Microsoft_DotNet_Interactive_Kql_Tests --> Microsoft_DotNet_Interactive_ExtensionLab
# Microsoft_DotNet_Interactive_Kql_Tests --> Microsoft_DotNet_Interactive_FSharp
# Microsoft_DotNet_Interactive_Kql_Tests --> Microsoft_DotNet_Interactive_Kql
# Microsoft_DotNet_Interactive_Mermaid --> Microsoft_DotNet_Interactive
# Microsoft_DotNet_Interactive_Mermaid_Tests --> Microsoft_DotNet_Interactive_CSharp
# Microsoft_DotNet_Interactive_Mermaid_Tests --> Microsoft_DotNet_Interactive_Mermaid
# Microsoft_DotNet_Interactive_Mermaid_Tests --> Microsoft_DotNet_Interactive_Tests
# Microsoft_DotNet_Interactive_PackageManagement --> Microsoft_DotNet_Interactive
# Microsoft_DotNet_Interactive_PowerShell --> Microsoft_DotNet_Interactive
# Microsoft_DotNet_Interactive_PowerShell --> Microsoft_DotNet_Interactive_Formatting
# Microsoft_DotNet_Interactive_PowerShell_Tests --> Microsoft_DotNet_Interactive_PowerShell
# Microsoft_DotNet_Interactive_PowerShell_Tests --> Microsoft_DotNet_Interactive_Tests
# Microsoft_DotNet_Interactive_SqlServer --> Microsoft_DotNet_Interactive
# Microsoft_DotNet_Interactive_SqlServer --> Microsoft_DotNet_Interactive_CSharp
# Microsoft_DotNet_Interactive_SqlServer_Tests --> Microsoft_DotNet_Interactive_CSharp
# Microsoft_DotNet_Interactive_SqlServer_Tests --> Microsoft_DotNet_Interactive_ExtensionLab
# Microsoft_DotNet_Interactive_SqlServer_Tests --> Microsoft_Dot

# %% [markdown]
# ### References for a specific project

# %%
let project = "Microsoft.DotNet.Interactive.FSharp"

Show.AllProjectsReferencedBy project
Show.Diagram.AllProjectsReferencedBy LeftToRight [ project ]

Show.AllProjectsThatReference project
Show.Diagram.AllProjectsThatReference LeftToRight [ project ]
# Out:
# <div>
#     <style>
#         .projInfoRefs .extraInfo { font-size: 0.9em; font-style: italic ; color: gray }
#         .projInfoRefs ul { list-style-type: none; }
#         .projInfoRefs input { display: none; }
#         .projInfoRefs input:checked ~ ul { display: none; }
#         .projInfoRefs input ~ label { font-weight: bold; }
#         .projInfoRefs input ~ label::before { content: '(-) '; }
#         .projInfoRefs input:checked ~ label::before { content: '(+) '; }
#     </style>
#     <div class="projInfoRefs">
#         <ul>
#             <li>
#                 <input id="44125e3d-832a-4de9-91af-55e3223d619f" type="checkbox"/>
#                 <label for="44125e3d-832a-4de9-91af-55e3223d619f">Microsoft.DotNet.Interactive.FSharp</label>
#                 <span class="extraInfo">references:</span>
#                 <ul>
#                     <li>
#                         <input checked="checked" id="7694f2cc-1f8a-49c6-8067-b832ab8a913c" type="checkbox"/>
#                         <label for="7694f2cc-1f8a-49c6-8067-b832ab8a913c">Microsoft.DotNet.Interactive</label>
#                         <span class="extraInfo">references:</span>
#                         <ul>
#                             <li>
#                                 <input checked="checked" id="205df0d2-742f-4ee0-bbc5-c59605c469c5" type="checkbox"/>
#                                 <label for="205df0d2-742f-4ee0-bbc5-c59605c469c5">Microsoft.DotNet.Interactive.Documents</label>
#                                 <span class="extraInfo">references:</span>
#                                 <ul></ul>
#                             </li>
#                             <li>
#                                 <input checked="checked" id="9e4a739f-8a3c-47ce-9bc7-86a9d3f52459" type="checkbox"/>
#                                 <label for="9e4a739f-8a3c-47ce-9bc7-86a9d3f52459">Microsoft.DotNet.Interactive.Formatting</label>
#                                 <span class="extraInfo">references:</span>
#                                 <ul></ul>
#                             </li>
#                         </ul>
#                     </li>
#                     <li>
#                         <input checked="checked" id="7b5c54e1-1e8f-49bf-a82a-f068fdf9c1e3" type="checkbox"/>
#                         <label for="7b5c54e1-1e8f-49bf-a82a-f068fdf9c1e3">Microsoft.DotNet.Interactive.Formatting</label>
#                         <span class="extraInfo">references:</span>
#                         <ul></ul>
#                     </li>
#                     <li>
#                         <input checked="checked" id="c78ac60a-c51e-4348-98bc-49900e28dee2" type="checkbox"/>
#                         <label for="c78ac60a-c51e-4348-98bc-49900e28dee2">Microsoft.DotNet.Interactive.PackageManagement</label>
#                         <span class="extraInfo">references:</span>
#                         <ul>
#                             <li>
#                                 <input checked="checked" id="62ddfc19-8b2d-4cb7-a267-66f72c6f2b81" type="checkbox"/>
#                                 <label for="62ddfc19-8b2d-4cb7-a267-66f72c6f2b81">Microsoft.DotNet.Interactive</label>
#                                 <span class="extraInfo">references:</span>
#                                 <ul>
#                                     <li>
#                                         <input checked="checked" id="9524c91a-6039-4629-a044-b0278e34343e" type="checkbox"/>
#                                         <label for="9524c91a-6039-4629-a044-b0278e34343e">Microsoft.DotNet.Interactive.Documents</label>
#                                         <span class="extraInfo">references:</span>
#                                         <ul></ul>
#                                     </li>
#                                     <li>
#                                         <input checked="checked" id="2a00ace1-5367-4f5e-8930-56b3367d1208" type="checkbox"/>
#                                         <label for="2a00ace1-5367-4f5e-8930-56b3367d1208">Microsoft.DotNet.Interactive.Formatting</label>
#                                         <span class="extraInfo">references:</span>
#                                         <ul></ul>
#                                     </li>
#                                 </ul>
#                             </li>
#                         </ul>
#                     </li>
#                 </ul>
#             </li>
#         </ul>
#     </div>
# </div>
# <div class="mermaidMarkdownContainer" style="background-color:white">
# <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.2.0/css/all.min.css">
# <script type="text/javascript">
#
# loadMermaid_532bee8b9a9c4ee8af6c6e2b27baa1c7 = () => {
#
#         (require.config({ 'paths': { 'context': '9.1.7', 'mermaidUri' : 'https://cdn.jsdelivr.net/npm/mermaid@9.1.7/dist/mermaid.min', 'urlArgs': 'cacheBuster=abdbfa4a17be4f5a828710a22bd81adc' }}) || require)(['mermaidUri'], (mermaid) => {
#
#             let renderTarget = document.getElementById('532bee8b9a9c4ee8af6c6e2b27baa1c7');
#             mermaid.mermaidAPI.render(
#                 'mermaid_532bee8b9a9c4ee8af6c6e2b27baa1c7',
#                 `stateDiagram-v2
# direction LR
# Microsoft_DotNet_Interactive_FSharp --> Microsoft_DotNet_Interactive
# Microsoft_DotNet_Interactive_FSharp --> Microsoft_DotNet_Interactive_Formatting
# Microsoft_DotNet_Interactive_FSharp --> Microsoft_DotNet_Interactive_PackageManagement
# Microsoft_DotNet_Interactive --> Microsoft_DotNet_Interactive_Documents
# Microsoft_DotNet_Interactive --> Microsoft_DotNet_Interactive_Formatting
# Microsoft_DotNet_Interactive_PackageManagement --> Microsoft_DotNet_Interactive
# Microsoft_DotNet_Interactive --> Microsoft_DotNet_Interactive_Documents
# Microsoft_DotNet_Interactive --> Microsoft_DotNet_Interactive_Formatting`,
#                 g => {
#                     renderTarget.innerHTML = g
#                 });
#         },
#         (error) => {
#             console.log(error);
#         });
# }
# // ensure `require` is available globally
# if ((typeof(require) !==  typeof(Function)) || (typeof(require.config) !== typeof(Function))) {
#     let require_script = document.createElement('script');
#     require_script.setAttribute('src', 'https://cdnjs.cloudflare.com/ajax/libs/require.js/2.3.6/require.min.js');
#     require_script.setAttribute('type', 'text/javascript');
#
#
#     require_script.onload = function() {
#         loadMermaid_532bee8b9a9c4ee8af6c6e2b27baa1c7();
#     };
#
#     document.getElementsByTagName('head')[0].appendChild(require_script);
# }
# else {
#     loadMermaid_532bee8b9a9c4ee8af6c6e2b27baa1c7();
# }
#
# </script>
# <div id="532bee8b9a9c4ee8af6c6e2b27baa1c7"></div>
# </div>
# <div>
#     <style>
#         .projInfoRefs .extraInfo { font-size: 0.9em; font-style: italic ; color: gray }
#         .projInfoRefs ul { list-style-type: none; }
#         .projInfoRefs input { display: none; }
#         .projInfoRefs input:checked ~ ul { display: none; }
#         .projInfoRefs input ~ label { font-weight: bold; }
#         .projInfoRefs input ~ label::before { content: '(-) '; }
#         .projInfoRefs input:checked ~ label::before { content: '(+) '; }
#     </style>
#     <div class="projInfoRefs">
#         <ul>
#             <li>
#                 <input id="5b8daf37-10e4-42bc-be9f-4a46a34fcd86" type="checkbox"/>
#                 <label for="5b8daf37-10e4-42bc-be9f-4a46a34fcd86">Microsoft.DotNet.Interactive.FSharp</label>
#                 <span class="extraInfo">is referenced by:</span>
#                 <ul>
#                     <li>
#                         <input checked="checked" id="017f5296-e12c-490d-9b20-8a08fa5e149f" type="checkbox"/>
#                         <label for="017f5296-e12c-490d-9b20-8a08fa5e149f">Microsoft.DotNet.Interactive.ApiCompatibility.Tests</label>
#                         <span class="extraInfo">is referenced by:</span>
#                         <ul></ul>
#                     </li>
#                     <li>
#                         <input checked="checked" id="a5c4c885-a24f-41ea-95fd-ba6d04fa3919" type="checkbox"/>
#                         <label for="a5c4c885-a24f-41ea-95fd-ba6d04fa3919">Microsoft.DotNet.Interactive.ExtensionLab.Tests</label>
#                         <span class="extraInfo">is referenced by:</span>
#                         <ul></ul>
#                     </li>
#                     <li>
#                         <input checked="checked" id="6cb8c54a-84d8-4ae0-9d0a-47f577caa06a" type="checkbox"/>
#                         <label for="6cb8c54a-84d8-4ae0-9d0a-47f577caa06a">Microsoft.DotNet.Interactive.FSharp.Tests</label>
#                         <span class="extraInfo">is referenced by:</span>
#                         <ul></ul>
#                     </li>
#                     <li>
#                         <input checked="checked" id="5dae726c-a931-48cc-9aeb-04ab7942c4fe" type="checkbox"/>
#                         <label for="5dae726c-a931-48cc-9aeb-04ab7942c4fe">Microsoft.DotNet.Interactive.Jupyter</label>
#                         <span class="extraInfo">is referenced by:</span>
#                         <ul>
#                             <li>
#                                 <input checked="checked" id="73c38607-3dd7-46cc-97f4-41607014f81f" type="checkbox"/>
#                                 <label for="73c38607-3dd7-46cc-97f4-41607014f81f">Microsoft.DotNet.Interactive.ApiCompatibility.Tests</label>
#                                 <span class="extraInfo">is referenced by:</span>
#                                 <ul></ul>
#                             </li>
#                             <li>
#                                 <input checked="checked" id="3767e466-7e2b-4338-9423-3e5641724c2f" type="checkbox"/>
#                                 <label for="3767e466-7e2b-4338-9423-3e5641724c2f">Microsoft.DotNet.Interactive.Jupyter.Tests</label>
#                                 <span class="extraInfo">is referenced by:</span>
#                                 <ul></ul>
#                             </li>
#                             <li>
#                                 <input checked="checked" id="69758164-f874-4ab0-afb0-947ea8067bab" type="checkbox"/>
#                                 <label for="69758164-f874-4ab0-afb0-947ea8067bab">Microsoft.DotNet.Interactive.Tests</label>
#                                 <span class="extraInfo">is referenced by:</span>
#                                 <ul>
#                                     <li>
#                                         <input checked="checked" id="86159836-36e9-4968-9d5e-287d5f7b3cd7" type="checkbox"/>
#                                         <label for="86159836-36e9-4968-9d5e-287d5f7b3cd7">Microsoft.DotNet.Interactive.AspNetCore.Tests</label>
#                                         <span class="extraInfo">is referenced by:</span>
#                                         <ul></ul>
#                                     </li>
#                                     <li>
#                                         <input checked="checked" id="de217d27-cef1-462d-b846-6039ee3e4632" type="checkbox"/>
#                                         <label for="de217d27-cef1-462d-b846-6039ee3e4632">Microsoft.DotNet.Interactive.Browser.Tests</label>
#                                         <span class="extraInfo">is referenced by:</span>
#                                         <ul></ul>
#                                     </li>
#                                     <li>
#                                         <input checked="checked" id="45baae0c-b40e-4566-841a-03ff6a9070fd" type="checkbox"/>
#                                         <label for="45baae0c-b40e-4566-841a-03ff6a9070fd">Microsoft.DotNet.Interactive.CSharp.Tests</label>
#                                         <span class="extraInfo">is referenced by:</span>
#                                         <ul></ul>
#                                     </li>
#                                     <li>
#                                         <input checked="checked" id="5849ec1e-89e8-4f5c-942a-7c1b61aa2146" type="checkbox"/>
#                                         <label for="5849ec1e-89e8-4f5c-942a-7c1b61aa2146">Microsoft.DotNet.Interactive.CSharpProject.Tests</label>
#                                         <span class="extraInfo">is referenced by:</span>
#                                         <ul></ul>
#                                     </li>
#                                     <li>
#                                         <input checked="checked" id="c63d8a7f-42f6-4df7-8f1c-bd0eb1cb2f6a" type="checkbox"/>
#                                         <label for="c63d8a7f-42f6-4df7-8f1c-bd0eb1cb2f6a">Microsoft.DotNet.Interactive.Documents.Tests</label>
#                                         <span class="extraInfo">is referenced by:</span>
#                                         <ul></ul>
#                                     </li>
#                                     <li>
#                                         <input checked="checked" id="68b7ba1c-b9a4-4ae1-917b-061a82367bd0" type="checkbox"/>
#                                         <label for="68b7ba1c-b9a4-4ae1-917b-061a82367bd0">Microsoft.DotNet.Interactive.HttpRequest.Tests</label>
#                                         <span class="extraInfo">is referenced by:</span>
#                                         <ul></ul>
#                                     </li>
#                                     <li>
#                                         <input checked="checked" id="e510f5a7-2f76-442e-ad22-fcbd37357e8e" type="checkbox"/>
#                                         <label for="e510f5a7-2f76-442e-ad22-fcbd37357e8e">Microsoft.DotNet.Interactive.Journey.Tests</label>
#                                         <span class="extraInfo">is referenced by:</span>
#                                         <ul></ul>
#                                     </li>
#                                     <li>
#                                         <input checked="checked" id="87dc01ad-0c40-48d9-9d43-462fb1db8b12" type="checkbox"/>
#                                         <label for="87dc01ad-0c40-48d9-9d43-462fb1db8b12">Microsoft.DotNet.Interactive.Jupyter.Tests</label>
#                                         <span class="extraInfo">is referenced by:</span>
#                                         <ul></ul>
#                                     </li>
#                                     <li>
#                                         <input checked="checked" id="c3071a80-267b-4d22-8d23-4a83f0884d23" type="checkbox"/>
#                                         <label for="c3071a80-267b-4d22-8d23-4a83f0884d23">Microsoft.DotNet.Interactive.Mermaid.Tests</label>
#                                         <span class="extraInfo">is referenced by:</span>
#                                         <ul><
# <div class="mermaidMarkdownContainer" style="background-color:white">
# <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.2.0/css/all.min.css">
# <script type="text/javascript">
#
# loadMermaid_433a1d059e8d4f50ba534d59f498b461 = () => {
#
#         (require.config({ 'paths': { 'context': '9.1.7', 'mermaidUri' : 'https://cdn.jsdelivr.net/npm/mermaid@9.1.7/dist/mermaid.min', 'urlArgs': 'cacheBuster=abdbfa4a17be4f5a828710a22bd81adc' }}) || require)(['mermaidUri'], (mermaid) => {
#
#             let renderTarget = document.getElementById('433a1d059e8d4f50ba534d59f498b461');
#             mermaid.mermaidAPI.render(
#                 'mermaid_433a1d059e8d4f50ba534d59f498b461',
#                 `stateDiagram-v2
# direction RL
# Microsoft_DotNet_Interactive_ApiCompatibility_Tests --> Microsoft_DotNet_Interactive_FSharp
# Microsoft_DotNet_Interactive_ExtensionLab_Tests --> Microsoft_DotNet_Interactive_FSharp
# Microsoft_DotNet_Interactive_FSharp_Tests --> Microsoft_DotNet_Interactive_FSharp
# Microsoft_DotNet_Interactive_Jupyter --> Microsoft_DotNet_Interactive_FSharp
# Microsoft_DotNet_Interactive_Kql_Tests --> Microsoft_DotNet_Interactive_FSharp
# Microsoft_DotNet_Interactive_SqlServer_Tests --> Microsoft_DotNet_Interactive_FSharp
# Microsoft_DotNet_Interactive_Tests --> Microsoft_DotNet_Interactive_FSharp
# Microsoft_DotNet_Interactive_VSCode --> Microsoft_DotNet_Interactive_FSharp
# dotnet_interactive --> Microsoft_DotNet_Interactive_FSharp
# Microsoft_DotNet_Interactive_ApiCompatibility_Tests --> Microsoft_DotNet_Interactive_Jupyter
# Microsoft_DotNet_Interactive_Jupyter_Tests --> Microsoft_DotNet_Interactive_Jupyter
# Microsoft_DotNet_Interactive_Tests --> Microsoft_DotNet_Interactive_Jupyter
# dotnet_interactive --> Microsoft_DotNet_Interactive_Jupyter
# Microsoft_DotNet_Interactive_AspNetCore_Tests --> Microsoft_DotNet_Interactive_Tests
# Microsoft_DotNet_Interactive_Browser_Tests --> Microsoft_DotNet_Interactive_Tests
# Microsoft_DotNet_Interactive_CSharp_Tests --> Microsoft_DotNet_Interactive_Tests
# Microsoft_DotNet_Interactive_CSharpProject_Tests --> Microsoft_DotNet_Interactive_Tests
# Microsoft_DotNet_Interactive_Documents_Tests --> Microsoft_DotNet_Interactive_Tests
# Microsoft_DotNet_Interactive_HttpRequest_Tests --> Microsoft_DotNet_Interactive_Tests
# Microsoft_DotNet_Interactive_Journey_Tests --> Microsoft_DotNet_Interactive_Tests
# Microsoft_DotNet_Interactive_Jupyter_Tests --> Microsoft_DotNet_Interactive_Tests
# Microsoft_DotNet_Interactive_Mermaid_Tests --> Microsoft_DotNet_Interactive_Tests
# Microsoft_DotNet_Interactive_PowerShell_Tests --> Microsoft_DotNet_Interactive_Tests
# dotnet_interactive_Tests --> Microsoft_DotNet_Interactive_Tests
# dotnet_interactive --> Microsoft_DotNet_Interactive_VSCode
# interface_generator --> Microsoft_DotNet_Interactive_VSCode
# Microsoft_DotNet_Interactive_AspNetCore_Tests --> dotnet_interactive
# Microsoft_DotNet_Interactive_Tests --> dotnet_interactive
# dotnet_interactive_Tests --> dotnet_interactive
# Microsoft_DotNet_Interactive_AspNetCore_Tests --> interface_generator
# dotnet_interactive_Tests --> interface_generator
# Microsoft_DotNet_Interactive_AspNetCore_Tests --> Microsoft_DotNet_Interactive_Tests
# Microsoft_DotNet_Interactive_Browser_Tests --> Microsoft_DotNet_Interactive_Tests
# Microsoft_DotNet_Interactive_CSharp_Tests --> Microsoft_DotNet_Interactive_Tests
# Microsoft_DotNet_Interactive_CSharpProject_Tests --> Microsoft_DotNet_Interactive_Tests
# Microsoft_DotNet_Interactive_Documents_Tests --> Microsoft_DotNet_Interactive_Tests
# Microsoft_DotNet_Interactive_HttpRequest_Tests --> Microsoft_DotNet_Interactive_Tests
# Microsoft_DotNet_Interactive_Journey_Tests --> Microsoft_DotNet_Interactive_Tests
# Microsoft_DotNet_Interactive_Jupyter_Tests --> Microsoft_DotNet_Interactive_Tests
# Microsoft_DotNet_Interactive_Mermaid_Tests --> Microsoft_DotNet_Interactive_Tests
# Microsoft_DotNet_Interactive_PowerShell_Tests --> Microsoft_DotNet_Interactive_Tests
# dotnet_interactive_Tests --> Microsoft_DotNet_Interactive_Tests`,
#                 g => {
#                     renderTarget.innerHTML = g
#                 });
#         },
#         (error) => {
#             console.log(error);
#         });
# }
# // ensure `require` is available globally
# if ((typeof(require) !==  typeof(Function)) || (typeof(require.config) !== typeof(Function))) {
#     let require_script = document.createElement('script');
#     require_script.setAttribute('src', 'https://cdnjs.cloudflare.com/ajax/libs/require.js/2.3.6/require.min.js');
#     require_script.setAttribute('type', 'text/javascript');
#
#
#     require_script.onload = function() {
#         loadMermaid_433a1d059e8d4f50ba534d59f498b461();
#     };
#
#     document.getElementsByTagName('head')[0].appendChild(require_script);
# }
# else {
#     loadMermaid_433a1d059e8d4f50ba534d59f498b461();
# }
#
# </script>
# <div id="433a1d059e8d4f50ba534d59f498b461"></div>
# </div>

# %% [markdown]
# ### References for multiple projects

# %%
let projects = [ "Microsoft.DotNet.Interactive.ExtensionLab" ; "Microsoft.DotNet.Interactive.Kql" ]

projects |> Seq.iter Show.AllProjectsReferencedBy
Show.Diagram.AllProjectsReferencedBy LeftToRight projects

projects |> Seq.iter Show.AllProjectsThatReference
Show.Diagram.AllProjectsThatReference LeftToRight projects
# Out:
# <div>
#     <style>
#         .projInfoRefs .extraInfo { font-size: 0.9em; font-style: italic ; color: gray }
#         .projInfoRefs ul { list-style-type: none; }
#         .projInfoRefs input { display: none; }
#         .projInfoRefs input:checked ~ ul { display: none; }
#         .projInfoRefs input ~ label { font-weight: bold; }
#         .projInfoRefs input ~ label::before { content: '(-) '; }
#         .projInfoRefs input:checked ~ label::before { content: '(+) '; }
#     </style>
#     <div class="projInfoRefs">
#         <ul>
#             <li>
#                 <input id="881cbfe0-ba75-46ca-82e5-13fe191db4ba" type="checkbox"/>
#                 <label for="881cbfe0-ba75-46ca-82e5-13fe191db4ba">Microsoft.DotNet.Interactive.ExtensionLab</label>
#                 <span class="extraInfo">references:</span>
#                 <ul>
#                     <li>
#                         <input checked="checked" id="0ccd733a-9c3a-446d-a0a3-5d900b3d32b7" type="checkbox"/>
#                         <label for="0ccd733a-9c3a-446d-a0a3-5d900b3d32b7">Microsoft.DotNet.Interactive</label>
#                         <span class="extraInfo">references:</span>
#                         <ul>
#                             <li>
#                                 <input checked="checked" id="9b3526e9-0c0b-449f-bc5d-18db3bcd2a3d" type="checkbox"/>
#                                 <label for="9b3526e9-0c0b-449f-bc5d-18db3bcd2a3d">Microsoft.DotNet.Interactive.Documents</label>
#                                 <span class="extraInfo">references:</span>
#                                 <ul></ul>
#                             </li>
#                             <li>
#                                 <input checked="checked" id="07a204f9-5b07-4e46-8e8c-9ee29746a979" type="checkbox"/>
#                                 <label for="07a204f9-5b07-4e46-8e8c-9ee29746a979">Microsoft.DotNet.Interactive.Formatting</label>
#                                 <span class="extraInfo">references:</span>
#                                 <ul></ul>
#                             </li>
#                         </ul>
#                     </li>
#                     <li>
#                         <input checked="checked" id="770576f2-bbb3-4a25-b780-a6ae3d521637" type="checkbox"/>
#                         <label for="770576f2-bbb3-4a25-b780-a6ae3d521637">Microsoft.DotNet.Interactive.CSharp</label>
#                         <span class="extraInfo">references:</span>
#                         <ul>
#                             <li>
#                                 <input checked="checked" id="247dead5-a52f-4c6a-8b37-6cf12e847635" type="checkbox"/>
#                                 <label for="247dead5-a52f-4c6a-8b37-6cf12e847635">Microsoft.DotNet.Interactive</label>
#                                 <span class="extraInfo">references:</span>
#                                 <ul>
#                                     <li>
#                                         <input checked="checked" id="6a6973a5-4ca2-41b0-a350-bd5a52f1e05b" type="checkbox"/>
#                                         <label for="6a6973a5-4ca2-41b0-a350-bd5a52f1e05b">Microsoft.DotNet.Interactive.Documents</label>
#                                         <span class="extraInfo">references:</span>
#                                         <ul></ul>
#                                     </li>
#                                     <li>
#                                         <input checked="checked" id="988167c9-5d99-466a-b0ba-3711436f35cd" type="checkbox"/>
#                                         <label for="988167c9-5d99-466a-b0ba-3711436f35cd">Microsoft.DotNet.Interactive.Formatting</label>
#                                         <span class="extraInfo">references:</span>
#                                         <ul></ul>
#                                     </li>
#                                 </ul>
#                             </li>
#                             <li>
#                                 <input checked="checked" id="aaffefb9-5ea9-4c55-8047-ed322baf57c2" type="checkbox"/>
#                                 <label for="aaffefb9-5ea9-4c55-8047-ed322baf57c2">Microsoft.DotNet.Interactive.Formatting</label>
#                                 <span class="extraInfo">references:</span>
#                                 <ul></ul>
#                             </li>
#                             <li>
#                                 <input checked="checked" id="a1cfc117-87c1-42c0-b4cf-8acf8516b616" type="checkbox"/>
#                                 <label for="a1cfc117-87c1-42c0-b4cf-8acf8516b616">Microsoft.DotNet.Interactive.PackageManagement</label>
#                                 <span class="extraInfo">references:</span>
#                                 <ul>
#                                     <li>
#                                         <input checked="checked" id="d702d5b1-18f9-47b4-b383-00e49b211e9a" type="checkbox"/>
#                                         <label for="d702d5b1-18f9-47b4-b383-00e49b211e9a">Microsoft.DotNet.Interactive</label>
#                                         <span class="extraInfo">references:</span>
#                                         <ul>
#                                             <li>
#                                                 <input checked="checked" id="fcb6e4a7-c366-4eba-968e-3080925ae8f6" type="checkbox"/>
#                                                 <label for="fcb6e4a7-c366-4eba-968e-3080925ae8f6">Microsoft.DotNet.Interactive.Documents</label>
#                                                 <span class="extraInfo">references:</span>
#                                                 <ul></ul>
#                                             </li>
#                                             <li>
#                                                 <input checked="checked" id="1647340b-47fc-4ce9-8872-cefe78448f74" type="checkbox"/>
#                                                 <label for="1647340b-47fc-4ce9-8872-cefe78448f74">Microsoft.DotNet.Interactive.Formatting</label>
#                                                 <span class="extraInfo">references:</span>
#                                                 <ul></ul>
#                                             </li>
#                                         </ul>
#                                     </li>
#                                 </ul>
#                             </li>
#                         </ul>
#                     </li>
#                     <li>
#                         <input checked="checked" id="f594b9a9-b08e-409b-ada5-297d657adae5" type="checkbox"/>
#                         <label for="f594b9a9-b08e-409b-ada5-297d657adae5">Microsoft.DotNet.Interactive.Formatting</label>
#                         <span class="extraInfo">references:</span>
#                         <ul></ul>
#                     </li>
#                 </ul>
#             </li>
#         </ul>
#     </div>
# </div>
# <div>
#     <style>
#         .projInfoRefs .extraInfo { font-size: 0.9em; font-style: italic ; color: gray }
#         .projInfoRefs ul { list-style-type: none; }
#         .projInfoRefs input { display: none; }
#         .projInfoRefs input:checked ~ ul { display: none; }
#         .projInfoRefs input ~ label { font-weight: bold; }
#         .projInfoRefs input ~ label::before { content: '(-) '; }
#         .projInfoRefs input:checked ~ label::before { content: '(+) '; }
#     </style>
#     <div class="projInfoRefs">
#         <ul>
#             <li>
#                 <input id="bd398a2e-9ff8-44ac-8b1c-9c7170bdb129" type="checkbox"/>
#                 <label for="bd398a2e-9ff8-44ac-8b1c-9c7170bdb129">Microsoft.DotNet.Interactive.Kql</label>
#                 <span class="extraInfo">references:</span>
#                 <ul>
#                     <li>
#                         <input checked="checked" id="df2afa01-7ae2-404e-b3f4-be5e7631388c" type="checkbox"/>
#                         <label for="df2afa01-7ae2-404e-b3f4-be5e7631388c">Microsoft.DotNet.Interactive</label>
#                         <span class="extraInfo">references:</span>
#                         <ul>
#                             <li>
#                                 <input checked="checked" id="1fa6e8be-2974-4f9f-b622-c498ac9b09a8" type="checkbox"/>
#                                 <label for="1fa6e8be-2974-4f9f-b622-c498ac9b09a8">Microsoft.DotNet.Interactive.Documents</label>
#                                 <span class="extraInfo">references:</span>
#                                 <ul></ul>
#                             </li>
#                             <li>
#                                 <input checked="checked" id="0d3ddb4c-1727-4579-8f49-3ad13078fff2" type="checkbox"/>
#                                 <label for="0d3ddb4c-1727-4579-8f49-3ad13078fff2">Microsoft.DotNet.Interactive.Formatting</label>
#                                 <span class="extraInfo">references:</span>
#                                 <ul></ul>
#                             </li>
#                         </ul>
#                     </li>
#                     <li>
#                         <input checked="checked" id="165292d8-76f4-4bd9-91e8-5d03177e0bf9" type="checkbox"/>
#                         <label for="165292d8-76f4-4bd9-91e8-5d03177e0bf9">Microsoft.DotNet.Interactive.PackageManagement</label>
#                         <span class="extraInfo">references:</span>
#                         <ul>
#                             <li>
#                                 <input checked="checked" id="b854f436-3817-4fa1-87f8-9da162fb451b" type="checkbox"/>
#                                 <label for="b854f436-3817-4fa1-87f8-9da162fb451b">Microsoft.DotNet.Interactive</label>
#                                 <span class="extraInfo">references:</span>
#                                 <ul>
#                                     <li>
#                                         <input checked="checked" id="2f330a11-8915-4dc6-89a5-be048f11cf7d" type="checkbox"/>
#                                         <label for="2f330a11-8915-4dc6-89a5-be048f11cf7d">Microsoft.DotNet.Interactive.Documents</label>
#                                         <span class="extraInfo">references:</span>
#                                         <ul></ul>
#                                     </li>
#                                     <li>
#                                         <input checked="checked" id="1106203c-6a66-41f7-9c0e-1f3dd4eb0413" type="checkbox"/>
#                                         <label for="1106203c-6a66-41f7-9c0e-1f3dd4eb0413">Microsoft.DotNet.Interactive.Formatting</label>
#                                         <span class="extraInfo">references:</span>
#                                         <ul></ul>
#                                     </li>
#                                 </ul>
#                             </li>
#                         </ul>
#                     </li>
#                 </ul>
#             </li>
#         </ul>
#     </div>
# </div>
# <div class="mermaidMarkdownContainer" style="background-color:white">
# <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.2.0/css/all.min.css">
# <script type="text/javascript">
#
# loadMermaid_66dea89a28334542a7972be691e6dcfc = () => {
#
#         (require.config({ 'paths': { 'context': '9.1.7', 'mermaidUri' : 'https://cdn.jsdelivr.net/npm/mermaid@9.1.7/dist/mermaid.min', 'urlArgs': 'cacheBuster=abdbfa4a17be4f5a828710a22bd81adc' }}) || require)(['mermaidUri'], (mermaid) => {
#
#             let renderTarget = document.getElementById('66dea89a28334542a7972be691e6dcfc');
#             mermaid.mermaidAPI.render(
#                 'mermaid_66dea89a28334542a7972be691e6dcfc',
#                 `stateDiagram-v2
# direction LR
# Microsoft_DotNet_Interactive_ExtensionLab --> Microsoft_DotNet_Interactive
# Microsoft_DotNet_Interactive_ExtensionLab --> Microsoft_DotNet_Interactive_CSharp
# Microsoft_DotNet_Interactive_ExtensionLab --> Microsoft_DotNet_Interactive_Formatting
# Microsoft_DotNet_Interactive_Kql --> Microsoft_DotNet_Interactive
# Microsoft_DotNet_Interactive_Kql --> Microsoft_DotNet_Interactive_PackageManagement
# Microsoft_DotNet_Interactive --> Microsoft_DotNet_Interactive_Documents
# Microsoft_DotNet_Interactive --> Microsoft_DotNet_Interactive_Formatting
# Microsoft_DotNet_Interactive_CSharp --> Microsoft_DotNet_Interactive
# Microsoft_DotNet_Interactive_CSharp --> Microsoft_DotNet_Interactive_Formatting
# Microsoft_DotNet_Interactive_CSharp --> Microsoft_DotNet_Interactive_PackageManagement
# Microsoft_DotNet_Interactive_PackageManagement --> Microsoft_DotNet_Interactive
# Microsoft_DotNet_Interactive --> Microsoft_DotNet_Interactive_Documents
# Microsoft_DotNet_Interactive --> Microsoft_DotNet_Interactive_Formatting`,
#                 g => {
#                     renderTarget.innerHTML = g
#                 });
#         },
#         (error) => {
#             console.log(error);
#         });
# }
# // ensure `require` is available globally
# if ((typeof(require) !==  typeof(Function)) || (typeof(require.config) !== typeof(Function))) {
#     let require_script = document.createElement('script');
#     require_script.setAttribute('src', 'https://cdnjs.cloudflare.com/ajax/libs/require.js/2.3.6/require.min.js');
#     require_script.setAttribute('type', 'text/javascript');
#
#
#     require_script.onload = function() {
#         loadMermaid_66dea89a28334542a7972be691e6dcfc();
#     };
#
#     document.getElementsByTagName('head')[0].appendChild(require_script);
# }
# else {
#     loadMermaid_66dea89a28334542a7972be691e6dcfc();
# }
#
# </script>
# <div id="66dea89a28334542a7972be691e6dcfc"></div>
# </div>
# <div>
#     <style>
#         .projInfoRefs .extraInfo { font-size: 0.9em; font-style: italic ; color: gray }
#         .projInfoRefs ul { list-style-type: none; }
#         .projInfoRefs input { display: none; }
#         .projInfoRefs input:checked ~ ul { display: none; }
#         .projInfoRefs input ~ label { font-weight: bold; }
#         .projInfoRefs input ~ label::before { content: '(-) '; }
#         .projInfoRefs input:checked ~ label::before { content: '(+) '; }
#     </style>
#     <div class="projInfoRefs">
#         <ul>
#             <li>
#                 <input id="02e2b18d-16aa-49cd-a1fb-b83547387ff0" type="checkbox"/>
#                 <label for="02e2b18d-16aa-49cd-a1fb-b83547387ff0">Microsoft.DotNet.Interactive.ExtensionLab</label>
#                 <span class="extraInfo">is referenced by:</span>
#                 <ul>
#                     <li>
#                         <input checked="checked" id="bb53ba31-d69e-4d72-a8ac-1a298bf71fe2" type="checkbox"/>
#                         <label for="bb53ba31-d69e-4d72-a8ac-1a298bf71fe2">Microsoft.DotNet.Interactive.ExtensionLab.Tests</label>
#                         <span class="extraInfo">is referenced by:</span>
#                         <ul></ul>
#                     </li>
#                     <li>
#                         <input checked="checked" id="8407aadd-7a7b-46cb-af4a-badf0dcc1ebc" type="checkbox"/>
#                         <label for="8407aadd-7a7b-46cb-af4a-badf0dcc1ebc">Microsoft.DotNet.Interactive.Kql.Tests</label>
#                         <span class="extraInfo">is referenced by:</span>
#                         <ul></ul>
#                     </li>
#                     <li>
#                         <input checked="checked" id="6a872436-c2bb-4ff5-bedb-8c7128c829bf" type="checkbox"/>
#                         <label for="6a872436-c2bb-4ff5-bedb-8c7128c829bf">Microsoft.DotNet.Interactive.SqlServer.Tests</label>
#                         <span class="extraInfo">is referenced by:</span>
#                         <ul></ul>
#                     </li>
#                 </ul>
#             </li>
#         </ul>
#     </div>
# </div>
# <div>
#     <style>
#         .projInfoRefs .extraInfo { font-size: 0.9em; font-style: italic ; color: gray }
#         .projInfoRefs ul { list-style-type: none; }
#         .projInfoRefs input { display: none; }
#         .projInfoRefs input:checked ~ ul { display: none; }
#         .projInfoRefs input ~ label { font-weight: bold; }
#         .projInfoRefs input ~ label::before { content: '(-) '; }
#         .projInfoRefs input:checked ~ label::before { content: '(+) '; }
#     </style>
#     <div class="projInfoRefs">
#         <ul>
#             <li>
#                 <input id="9f5babea-2efc-4068-b792-1baadae4d9da" type="checkbox"/>
#                 <label for="9f5babea-2efc-4068-b792-1baadae4d9da">Microsoft.DotNet.Interactive.Kql</label>
#                 <span class="extraInfo">is referenced by:</span>
#                 <ul>
#                     <li>
#                         <input checked="checked" id="2099239d-13d0-410f-a1f7-a0a3de3ed507" type="checkbox"/>
#                         <label for="2099239d-13d0-410f-a1f7-a0a3de3ed507">Microsoft.DotNet.Interactive.ApiCompatibility.Tests</label>
#                         <span class="extraInfo">is referenced by:</span>
#                         <ul></ul>
#                     </li>
#                     <li>
#                         <input checked="checked" id="db572fc2-1e55-444c-a9b9-3f6d5b77dd62" type="checkbox"/>
#                         <label for="db572fc2-1e55-444c-a9b9-3f6d5b77dd62">Microsoft.DotNet.Interactive.Kql.Tests</label>
#                         <span class="extraInfo">is referenced by:</span>
#                         <ul></ul>
#                     </li>
#                 </ul>
#             </li>
#         </ul>
#     </div>
# </div>
# <div class="mermaidMarkdownContainer" style="background-color:white">
# <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.2.0/css/all.min.css">
# <script type="text/javascript">
#
# loadMermaid_c52880f2d2cb4a34a8093061d1e63db5 = () => {
#
#         (require.config({ 'paths': { 'context': '9.1.7', 'mermaidUri' : 'https://cdn.jsdelivr.net/npm/mermaid@9.1.7/dist/mermaid.min', 'urlArgs': 'cacheBuster=abdbfa4a17be4f5a828710a22bd81adc' }}) || require)(['mermaidUri'], (mermaid) => {
#
#             let renderTarget = document.getElementById('c52880f2d2cb4a34a8093061d1e63db5');
#             mermaid.mermaidAPI.render(
#                 'mermaid_c52880f2d2cb4a34a8093061d1e63db5',
#                 `stateDiagram-v2
# direction RL
# Microsoft_DotNet_Interactive_ExtensionLab_Tests --> Microsoft_DotNet_Interactive_ExtensionLab
# Microsoft_DotNet_Interactive_Kql_Tests --> Microsoft_DotNet_Interactive_ExtensionLab
# Microsoft_DotNet_Interactive_SqlServer_Tests --> Microsoft_DotNet_Interactive_ExtensionLab
# Microsoft_DotNet_Interactive_ApiCompatibility_Tests --> Microsoft_DotNet_Interactive_Kql
# Microsoft_DotNet_Interactive_Kql_Tests --> Microsoft_DotNet_Interactive_Kql`,
#                 g => {
#                     renderTarget.innerHTML = g
#                 });
#         },
#         (error) => {
#             console.log(error);
#         });
# }
# // ensure `require` is available globally
# if ((typeof(require) !==  typeof(Function)) || (typeof(require.config) !== typeof(Function))) {
#     let require_script = document.createElement('script');
#     require_script.setAttribute('src', 'https://cdnjs.cloudflare.com/ajax/libs/require.js/2.3.6/require.min.js');
#     require_script.setAttribute('type', 'text/javascript');
#
#
#     require_script.onload = function() {
#         loadMermaid_c52880f2d2cb4a34a8093061d1e63db5();
#     };
#
#     document.getElementsByTagName('head')[0].appendChild(require_script);
# }
# else {
#     loadMermaid_c52880f2d2cb4a34a8093061d1e63db5();
# }
#
# </script>
# <div id="c52880f2d2cb4a34a8093061d1e63db5"></div>
# </div>
